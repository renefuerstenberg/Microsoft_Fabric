# %% [markdown]
# # Parameter

# %%
lakehouse = "lakehouse_gold" # Enter the name or ID of the lakehouse
workspace = "Fabric WS Freudenberg SE" # Enter the name or ID of the workspace in which the lakehouse exists
# Out:
# StatementMeta(, 2ba54842-4f85-4a31-b0fd-1c9fd60ba1c6, 5, Finished, Available, Finished)

# %% [markdown]
# # Import Libraries

# %%
import sempy_labs as labs
import sempy_labs.lakehouse as lake
import sempy_labs.report as rep
from sempy_labs import migration, directlake, admin, graph, theme, mirrored_azure_databricks_catalog
from sempy_labs.tom import connect_semantic_model
from sempy_labs.report import connect_report
# Out:
# StatementMeta(, 2ba54842-4f85-4a31-b0fd-1c9fd60ba1c6, 6, Finished, Available, Finished)

# %% [markdown]
# # Optimize Delta Tables

# %%
# Example 1: Optimize a single table
#lake.optimize_lakehouse_tables(tables='MyTable', lakehouse=lakehouse, workspace=workspace)

# Example 2: Optimize several tables
#lake.optimize_lakehouse_tables(tables=['MyTable', 'MySecondTable'], lakehouse=lakehouse, workspace=workspace)

# Example 3: Optimize all delta tables within the lakehouse
lake.optimize_lakehouse_tables(tables=None, lakehouse=lakehouse, workspace=workspace)
# Out:
# StatementMeta(, 2ba54842-4f85-4a31-b0fd-1c9fd60ba1c6, 7, Finished, Available, Finished)

# %% [markdown]
# # Delete old Files with Vacuum

# %%
retain_n_hours = "168" # The number of hours to retain historical versions of Delta table files

# Example 1: Vacuum a single table
#lake.vacuum_lakehouse_tables(tables='MyTable', lakehouse=lakehouse, workspace=workspace)

# Example 2: Vacuum several tables
#lake.vacuum_lakehouse_tables(tables=['MyTable', 'MySecondTable'], lakehouse=lakehouse, workspace=workspace)

# Example 3: Vacuum all delta tables within the lakehouse
lake.vacuum_lakehouse_tables(tables=None, lakehouse=lakehouse, workspace=workspace)
# Out:
# StatementMeta(, 2ba54842-4f85-4a31-b0fd-1c9fd60ba1c6, 8, Finished, Available, Finished)
# StatementMeta(, 2ba54842-4f85-4a31-b0fd-1c9fd60ba1c6, 9, Finished, Available, Finished)

# %% [markdown]
# #
